# %%
# import numpy as np
# import os

# # Define paths
# seis_path = r"C:\MAIN\DA-IICT\SEM2\DL\DL project\DL dataset\fault3D\train\seis"    # Update with actual path
# fault_path = r"C:\MAIN\DA-IICT\SEM2\DL\DL project\DL dataset\fault3D\train\fault"  # Update with actual path

# # List first 5 files
# file_indices = [0, 1, 2, 3, 4]

# # Function to load .dat files
# def load_dat(file_path):
#     data = np.fromfile(file_path, dtype=np.float32)
#     return data

# # Load and check shapes
# for idx in file_indices:
#     seis_file = os.path.join(seis_path, f"{idx}.dat")
#     fault_file = os.path.join(fault_path, f"{idx}.dat")
    
#     seis_data = load_dat(seis_file)
#     fault_data = load_dat(fault_file)

#     print(f"File {idx}.dat - Seismic Shape: {seis_data.shape}, Fault Shape: {fault_data.shape}")
# Out:
# File 0.dat - Seismic Shape: (2097152,), Fault Shape: (2097152,)
# File 1.dat - Seismic Shape: (2097152,), Fault Shape: (2097152,)
# File 2.dat - Seismic Shape: (2097152,), Fault Shape: (2097152,)
# File 3.dat - Seismic Shape: (2097152,), Fault Shape: (2097152,)
# File 4.dat - Seismic Shape: (2097152,), Fault Shape: (2097152,)

# %%
# import matplotlib.pyplot as plt

# # Reshape and visualize one sample
# sample_idx = 0  # Pick any file index to visualize

# seis_data = load_dat(os.path.join(seis_path, f"{sample_idx}.dat")).reshape(128, 128, 128)
# fault_data = load_dat(os.path.join(fault_path, f"{sample_idx}.dat")).reshape(128, 128, 128)

# fig, axes = plt.subplots(2, 3, figsize=(12, 8))

# # Pick some slices to visualize
# slice_indices = [32, 64, 96]

# for i, idx in enumerate(slice_indices):
#     axes[0, i].imshow(seis_data[idx, :, :], cmap="gray")
#     axes[0, i].set_title(f"Seismic - Slice {idx}")
#     axes[0, i].axis("off")

#     axes[1, i].imshow(fault_data[idx, :, :], cmap="gray")
#     axes[1, i].set_title(f"Fault - Slice {idx}")
#     axes[1, i].axis("off")

# plt.show()
